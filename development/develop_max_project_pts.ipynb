# %% [markdown]
# Code for development and testing of the function max_project_pts

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

from janelia_core.visualization.image_generation import max_project_pts

# %%
box_position = np.asarray([[-1000, -1000],[1000.01, 1000.01]]) # Boundaries of box the dots are in

n_dots = 100000
dot_positions = np.random.rand(n_dots,2)*2000 - 1000
dot_vls = np.random.randn(n_dots)

n_divisions = np.asarray([1000, 1000])
    
dot_dim_width = np.asarray([100, 100])

# %%
im, inds = max_project_pts(dot_positions=dot_positions, dot_vls=dot_vls, box_position=box_position,
                n_divisions=n_divisions, dot_dim_width=dot_dim_width)

# %%
# %matplotlib notebook
plt.imshow(im)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">
