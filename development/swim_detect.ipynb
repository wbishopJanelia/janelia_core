# %% [markdown]
# # Development of code for detection of swim bouts

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path
import pickle 

import matplotlib.pyplot as plt

from janelia_core.dataprocessing.ahrens_lab import extract_swims_from_ephys
from janelia_core.dataprocessing.dataset import ROIDataset

# %% [markdown]
# ## Load of raw data

# %%
base_folder = Path(r'E:\bishop_work\ahrens_two_color\20161109_2_1_6dpf_GFAP_GC_Huc_RG_GA_CL_fb_OL_f0_0GAIN_20161109_211950\processed')
dataset_file = 'full_dataset.pkl'

# %%
# Load the data
with open(base_folder / dataset_file, 'rb') as f: 
    dataset = ROIDataset.from_dict(pickle.load(f))

# %% [markdown]
# ## Plot raw data

# %%
ch_inds = [5, 6]

# %%
ephys_data = dataset.ts_data['ephys']['vls']

# %%
plt.plot(ephys_data[0:100,5])
