# %% [markdown]
# Notebook for developing the function colorized_tbl

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

from janelia_core.visualization.matrix_visualization import colorized_tbl

# %% [markdown]
# ## Parameters go here

# %%
tbl = np.asarray([[0, 1.123, 2], [-3, -4.45, 5], [6, 7, 8]])

# %%
colorized_tbl(tbl=tbl, tbl_fontsize=12, tbl_values_x_offset=.10, dim_0_lbls=['A test', 'B test', 'C test'], 
              dim_1_lbls=['E test', 'F test', 'G test_test'], cmap='spring',
              label_fontsize=20, xtick_rotation=90, ytick_rotation=45)
